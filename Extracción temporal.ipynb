# %%
import pandas as pd
import fix_yahoo_finance as yf
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pnl = yf.download([x[0:-1] for x in list(open('Stickers.csv'))],start='2016-01-01')
# Out:
# [*********************100%***********************]  505 of 505 downloaded

# %%
df = pnl.to_frame().unstack(level=1)
X = df['Adj Close'].reset_index().drop(['Date'],axis=1)
X.head()
# Out:
# minor          A        AAL         AAP        AAPL       ABBV        ABC  \
# 0      39.889591  40.034653  151.606461  101.014183  53.132004  98.035957
# 1      39.752350  39.652996  150.570786   98.482841  52.910660  99.469872
# 2      39.928806  40.347797  146.587433   96.555573  52.919880  97.949341
# 3      38.232834  39.584499  148.210632   92.480476  52.763092  94.821655
# 4      37.830906  39.506207  144.954269   92.969490  51.324356  94.273102
#
# minor        ABT        ACN       ADBE        ADI    ...             XL  \
# 0      40.731670  97.839996  91.970001  51.542179    ...      36.159698
# 1      40.722183  98.349213  92.339996  51.163475    ...      36.235405
# 2      40.380615  98.157059  91.019997  48.985897    ...      35.923115
# 3      39.412853  95.274612  89.110001  47.736160    ...      35.175507
# 4      38.587395  94.352219  87.849998  47.319588    ...      34.494141
#
# minor       XLNX        XOM       XRAY        XRX        XYL        YUM  \
# ...

# %%
X.to_csv('DatosH.csv',index=False)
